# %%
# !pip install pymongo
# !pip install dataprep
# Out:
# Requirement already satisfied: pymongo in c:\users\ajay kumar\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from pymongo) (2.3.0)
# Collecting dataprep
#   Downloading dataprep-0.4.5-py3-none-any.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0,>=4.48 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (4.67.1)
# Collecting wordcloud<2.0,>=1.8
#   Downloading wordcloud-1.9.4-cp310-cp310-win_amd64.whl (299 kB)
#      -------------------------------------- 299.8/299.8 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: dask[array,dataframe,delayed]>=2022.3.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (2022.7.0)
# Requirement already satisfied: pydantic<2.0,>=1.6 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (1.10.15)
# Collecting metaphone<0.7,>=0.6
#   Downloading Metaphone-0.6.tar.gz (14 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting varname<0.9.0,>=0.8.1
#   Downloading varname-0.8.3-py3-none-any.whl (21 kB)
# Collecting python-stdnum<2.0,>=1.16
#   Downloading python_stdnum-1.20-py2.py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 4.0 MB/s eta 0:00:00
# Collecting jsonpath-ng<2.0,>=1.5
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: numpy<2.0,>=1.21 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (1.24.3)
# Requirement already satisfied: flask<3,>=2 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (2.2.2)
# Requirement already satisfied: scipy<2.0,>=1.8 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (1.10.0)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (3.9.5)
# Collecting regex<2022.0.0,>=2021.8.3
#   Downloading regex-2021.11.10-cp310-cp310-win_amd64.whl (273 kB)
#      -------------------------------------- 273.3/273.3 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: bokeh<3,>=2 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (2.4.3)
# Collecting python-crfsuite==0.9.8
#   Downloading python_crfsuite-0.9.8-cp310-cp310-win_amd64.whl (158 kB)
#      -------------------------------------- 158.9/158.9 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2.0,>=1.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (1.5.3)
# Collecting pydot<2.0.0,>=1.4.2
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting rapidfuzz<3.0.0,>=2.1.2
#   Downloading rapidfuzz-2.15.2-cp310-cp310-win_amd64.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (7.6.5)
# Collecting jinja2<3.1,>=3.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.6/133.6 kB 7.7 MB/s eta 0:00:00
# Collecting sqlalchemy==1.3.24
#   Downloading SQLAlchemy-1.3.24.tar.gz (6.4 MB)
#      ---------------------------------------- 6.4/6.4 MB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting flask_cors<4.0.0,>=3.0.10
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.7 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dataprep) (3.7)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.4.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (23.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.9.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ajay kumar\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ajay kumar\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (4.12.2)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\ajay kumar\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\ajay kumar\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (24.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (9.4.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2024.5.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.12.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2.0.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\ajay kumar\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (2.2.2)
# Requirement already satisfied: click>=8.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (8.1.7)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (2.0.1)
# Requirement already satisfied: Six in c:\users\ajay kumar\anaconda3\lib\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.7.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (8.10.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from jinja2<3.1,>=3.0->dataprep) (2.1.1)
# Requirement already satisfied: ply in c:\users\ajay kumar\anaconda3\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (3.11)
# Requirement already satisfied: joblib in c:\users\ajay kumar\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2025.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\ajay kumar\anaconda3\lib\site-packages (from pydot<2.0.0,>=1.4.2->dataprep) (3.0.9)
# Requirement already satisfied: colorama in c:\users\ajay kumar\anaconda3\lib\site-packages (from tqdm<5.0,>=4.48->dataprep) (0.4.6)
# Requirement already satisfied: executing<0.9.0,>=0.8.3 in c:\users\ajay kumar\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.8.3)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (2.0.5)
# Requirement already satisfied: pure_eval<1.0.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\ajay kumar\anaconda3\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.7.0)
# Requirement already satisfied: nest-asyncio in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (7.3.4)
# Requirement already satisfied: psutil in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (23.2.0)
# Requirement already satisfied: decorator in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.36)
# Requirement already satisfied: pickleshare in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: backcall in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.18.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\ajay kumar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.1)
# Requirement already satisfied: jupyter-core in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (5.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.17.3)
# Requirement already satisfied: locket in c:\users\ajay kumar\anaconda3\lib\site-packages (from partd>=0.3.10->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.5.2)
# Requirement already satisfied: idna>=2.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (3.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajay kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: entrypoints in c:\users\ajay kumar\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ajay kumar\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (3.11.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\ajay kumar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.5.4)
# Requirement already satisfied: prometheus-client in c:\users\ajay kumar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\ajay kumar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.3.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\ajay kumar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ajay kumar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.17.1)
# Requirement already satisfied: wcwidth in c:\users\ajay kumar\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.2)
# Requirement already satisfied: lxml in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.9.1)
# Requirement already satisfied: bleach in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.1.0)
# Requirement already satisfied: tinycss2 in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ajay kumar\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ajay kumar\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\ajay kumar\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\ajay kumar\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ajay kumar\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\ajay kumar\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ajay kumar\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\ajay kumar\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.21)
# Building wheels for collected packages: sqlalchemy, metaphone
#   Building wheel for sqlalchemy (setup.py): started
#   Building wheel for sqlalchemy (setup.py): finished with status 'done'
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.24-cp310-cp310-win_amd64.whl size=1203282 sha256=d41cb595feb884baadc8a736c2230a96ff4abb801cf83c5bf3873bac26811fb0
#   Stored in directory: c:\users\ajay kumar\appdata\local\pip\cache\wheels\c8\47\30\58f5319511b287d4cf145aa940abec1e7824bba5bd8f4de0b3
#   Building wheel for metaphone (setup.py): started
#   Building wheel for metaphone (setup.py): finished with status 'done'
#   Created wheel for metaphone: filename=Metaphone-0.6-py3-none-any.whl size=13945 sha256=d4683e4ec068dcacce3f0c17f3b9de90d76633328a34c9206248e157cd79561d
#   Stored in directory: c:\users\ajay kumar\appdata\local\pip\cache\wheels\91\df\55\49d1d0c09e7262d3e6a8ff232f4fb28380426e0db4169cea36
# Successfully built sqlalchemy metaphone
# Installing collected packages: regex, python-stdnum, python-crfsuite, metaphone, sqlalchemy, rapidfuzz, pydot, jsonpath-ng, jinja2, varname, wordcloud, flask_cors, dataprep
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.7.9
#     Uninstalling regex-2022.7.9:
#       Successfully uninstalled regex-2022.7.9
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
#   Attempting uninstall: pydot
#     Found existing installation: pydot 2.0.0
#     Uninstalling pydot-2.0.0:
#       Successfully uninstalled pydot-2.0.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
#   Attempting uninstall: flask_cors
#     Found existing installation: Flask-Cors 4.0.1
#     Uninstalling Flask-Cors-4.0.1:
#       Successfully uninstalled Flask-Cors-4.0.1
# Successfully installed dataprep-0.4.5 flask_cors-3.0.10 jinja2-3.0.3 jsonpath-ng-1.7.0 metaphone-0.6 pydot-1.4.2 python-crfsuite-0.9.8 python-stdnum-1.20 rapidfuzz-2.15.2 regex-2021.11.10 sqlalchemy-1.3.24 varname-0.8.3 wordcloud-1.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 2.12.2 requires pytz<2025, but you have pytz 2025.2 which is incompatible.
# mlflow 2.12.2 requires sqlalchemy<3,>=1.4.0, but you have sqlalchemy 1.3.24 which is incompatible.
# langchain 0.2.15 requires SQLAlchemy<3,>=1.4, but you have sqlalchemy 1.3.24 which is incompatible.

# %%
import pymongo
import pandas as pd
import dataprep.eda.create_report as report
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings("ignore")

# %%
ajay = pymongo.MongoClient("mongodb+srv://ajaykumar:ajay9095@cluster-1.npktwbc.mongodb.net/")
db = ajay.sample_airbnb
col = db.air_bnb_data

# %% [markdown]
# **Primary Table**

# %%
data = []
for i in col.find( {}, {'_id':1,'listing_url':1,'name':1,'property_type':1,'room_type':1,'bed_type':1,
                        'minimum_nights':1,'maximum_nights':1,'cancellation_policy':1,'accommodates':1,
                        'bedrooms':1,'beds':1,'number_of_reviews':1,'bathrooms':1,'price':1,
                        'cleaning_fee':1,'extra_people':1,'guests_included':1,'images.picture_url':1,
                        'review_scores.review_scores_rating':1} ):
    data.append(i)

df_1 = pd.DataFrame(data)
df_1['images'] = df_1['images'].apply(lambda x: x['picture_url'])
df_1['review_scores'] = df_1['review_scores'].apply(lambda x: x.get('review_scores_rating',0))
df_1.head()
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
# 3  10084023  https://www.airbnb.com/rooms/10084023
# 4  10091713  https://www.airbnb.com/rooms/10091713
#
#                                                name      property_type  \
# 0               New York City - Upper West Side Apt          Apartment
# 1               Double and triple rooms Blue mosque  Bed and breakfast
# 2                Soho Cozy, Spacious and Convenient          Apartment
# 3                 City center private room with bed         Guesthouse
# 4  Surry Hills Studio - Your Perfect Base in Sydney          Apartment
#
#          room_type  bed_type minimum_nights maximum_nights  \
# 0     Private room  Real Bed             12            360
# 1     Private room  Real Bed              1           1125
# 2  Entire home/apt  Real Bed              4             20
# 3     Private room     Futon              1            500
# 4  Entire home/apt  Real Bed             10             21
#
#            cancellation_policy  accommodates  bedrooms  beds  \
# 0  strict_14_with_grace_period             2       1.0   1.0
# 1                     moderate             3       1.0   2.0
# 2                     flexible             3       1.0   2.0
# 3  strict_14_with_grace_period             1       1.0   1.0
# 4  strict_14_with_grace_period             2       0.0   1.0
#
#    number_of_reviews  bathrooms  price  cleaning_fee  extra_people  \
# 0                 70        1.0    135         135.0             0
# 1                 29        1.0    121           NaN             0
# 2                  3        1.0    699           NaN             0
# 3                 81        1.0    181          50.0           100
# 4                 64        1.0    181          50.0             0
#
#    guests_included                                             images  \
# 0                1  https://a0.muscache.com/im/pictures/15074036/a...
# 1                1  https://a0.muscache.com/im/pictures/68de30b5-e...
# 2                1  https://a0.muscache.com/im/pictures/4533a1dc-6...
# 3                1  https://a0.muscache.com/im/pictures/e6275515-7...
# 4                1  https://a0.muscache.com/im/pictures/f8eaba4e-d...
#
#    review_scores
# 0             94
# 1             92
# 2            100
# 3             92
# 4             95

# %%
report(df_1)

# %%
df_1.isnull().sum()
# Out:
# _id                       0
# listing_url               0
# name                      0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# cleaning_fee           1531
# extra_people              0
# guests_included           0
# images                    0
# review_scores             0
# dtype: int64

# %%
df_1['bedrooms'].fillna(0, inplace=True)
df_1['beds'].fillna(0, inplace=True)
df_1['bathrooms'].fillna(0, inplace=True)
df_1['cleaning_fee'].fillna('Not Specified', inplace=True)
df_1.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# cleaning_fee           0
# extra_people           0
# guests_included        0
# images                 0
# review_scores          0
# dtype: int64

# %%
df_1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms              float64
# price                    int64
# cleaning_fee            object
# extra_people             int64
# guests_included          int64
# images                  object
# review_scores            int64
# dtype: object

# %%
df_1['minimum_nights'] = df_1['minimum_nights'].astype(int)
df_1['maximum_nights'] = df_1['maximum_nights'].astype(int)
df_1['bedrooms'] = df_1['bedrooms'].astype(int)
df_1['beds'] = df_1['beds'].astype(int)
df_1['bathrooms'] = df_1['bathrooms'].astype(str).astype(float)
df_1['price'] = df_1['price'].astype(str).astype(float).astype(int)
df_1['cleaning_fee'] = df_1['cleaning_fee'].apply(lambda x: int(float(str(x))) if x != 'Not Specified' else 'Not Specified')
df_1['extra_people'] = df_1['extra_people'].astype(str).astype(float).astype(int)
df_1['guests_included'] = df_1['guests_included'].astype(str).astype(int)

# %%
df_1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights           int32
# maximum_nights           int32
# cancellation_policy     object
# accommodates             int64
# bedrooms                 int32
# beds                     int32
# number_of_reviews        int64
# bathrooms              float64
# price                    int32
# cleaning_fee            object
# extra_people             int32
# guests_included          int32
# images                  object
# review_scores            int64
# dtype: object

# %%
df_1.describe().T
# Out:
#                     count          mean           std  min   25%     50%  \
# minimum_nights     5555.0  5.564356e+00  2.261386e+01  1.0   1.0     2.0
# maximum_nights     5555.0  1.382776e+06  5.256920e+07  1.0  59.0  1125.0
# accommodates       5555.0  3.505851e+00  2.297019e+00  1.0   2.0     3.0
# bedrooms           5555.0  1.410441e+00  1.042334e+00  0.0   1.0     1.0
# beds               5555.0  2.066607e+00  1.620858e+00  0.0   1.0     2.0
# number_of_reviews  5555.0  2.760648e+01  4.979838e+01  0.0   1.0     5.0
# bathrooms          5555.0  1.288839e+00  7.037643e-01  0.0   1.0     1.0
# price              5555.0  2.787662e+02  8.422155e+02  9.0  70.0   129.0
# extra_people       5555.0  2.279190e+01  6.933151e+01  0.0   0.0     0.0
# guests_included    5555.0  1.747435e+00  1.487352e+00  1.0   1.0     1.0
# review_scores      5555.0  6.839568e+01  4.182983e+01  0.0   0.0    92.0
#
#                       75%           max
# minimum_nights        3.0  1.250000e+03
# maximum_nights     1125.0  2.147484e+09
# accommodates          4.0  1.600000e+01
# bedrooms              2.0  2.000000e+01
# beds                  3.0  2.500000e+01
# number_of_reviews    32.0  5.330000e+02
# bathrooms             1.0  1.600000e+01
# price               280.0  4.884200e+04
# extra_people         20.0  2.346000e+03
# guests_included       2.0  1.600000e+01
# review_scores        98.0  1.000000e+02

# %%
df_1.head(2)
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
#
#                                   name      property_type     room_type  \
# 0  New York City - Upper West Side Apt          Apartment  Private room
# 1  Double and triple rooms Blue mosque  Bed and breakfast  Private room
#
#    bed_type  minimum_nights  maximum_nights          cancellation_policy  \
# 0  Real Bed              12             360  strict_14_with_grace_period
# 1  Real Bed               1            1125                     moderate
#
#    accommodates  bedrooms  beds  number_of_reviews  bathrooms  price  \
# 0             2         1     1                 70        1.0    135
# 1             3         1     2                 29        1.0    121
#
#     cleaning_fee  extra_people  guests_included  \
# 0            135             0                1
# 1  Not Specified             0                1
#
#                                               images  review_scores
# 0  https://a0.muscache.com/im/pictures/15074036/a...             94
# 1  https://a0.muscache.com/im/pictures/68de30b5-e...             92

# %% [markdown]
# **Host**

# %%
host = []
for i in col.find( {}, {'_id':1, 'host':1}):
    host.append(i)

df_host = pd.DataFrame(host)
host_keys = list(df_host.iloc[0,1].keys())
host_keys.remove('host_about')

for i in host_keys:
    if i == 'host_response_time':
        df_host['host_response_time'] = df_host['host'].apply(lambda x: x['host_response_time'] if 'host_response_time' in x else 'Not Specified')
    else:
        df_host[i] = df_host['host'].apply(lambda x: x[i] if i in x and x[i]!='' else 'Not Specified')

df_host.drop(columns=['host'], inplace=True)
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0   1003530    454250    https://www.airbnb.com/users/show/454250
# 1  10133554  52004703  https://www.airbnb.com/users/show/52004703
# 2  10059872  51624384  https://www.airbnb.com/users/show/51624384
# 3  10084023  51744313  https://www.airbnb.com/users/show/51744313
# 4  10091713  13764143  https://www.airbnb.com/users/show/13764143
#
#      host_name                      host_location  host_response_time  \
# 0        Greta  New York, New York, United States      within an hour
# 1  Mehmet Emin         Istanbul, İstanbul, Turkey  within a few hours
# 2     Giovanni               Hong Kong, Hong Kong       Not Specified
# 3           Yi                      United States      within an hour
# 4          Ben         New South Wales, Australia       Not Specified
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/f1022be4-e...
# 1  https://a0.muscache.com/im/pictures/user/4cb6b...
# 2  https://a0.muscache.com/im/pictures/264b82a7-7...
# 3  https://a0.muscache.com/im/pictures/user/a204d...
# 4  https://a0.muscache.com/im/pictures/03c4d82b-7...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 1  https://a0.muscache.com/im/pictures/user/4cb6b...      Not Specified
# 2  https://a0.muscache.com/im/pictures/264b82a7-7...               Soho
# 3  https://a0.muscache.com/im/pictures/user/a204d...       Shek Kip Mei
# 4  https://a0.muscache.com/im/pictures/03c4d82b-7...        Surry Hills
#
#   host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                100               True                  True
# 1                100              False                  True
# 2      Not Specified              False                  True
# 3                100              False                  True
# 4      Not Specified              False                  True
#
#    host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    True                    3                          3
# 1                    True                    2                          2
# 2                   False                    1                          1
# 3                    True                    2                          2
# 4                    True                    1                          1
#
#                                   host_verifications
# 0  [email, phone, reviews, jumio, offline_governm...
# 1  [email, phone, facebook, reviews, jumio, offli...
# 2      [email, phone, reviews, jumio, government_id]
# 3  [email, phone, reviews, jumio, offline_governm...
# 4  [email, phone, google, reviews, jumio, offline...

# %%
df_host['host_is_superhost'] = df_host['host_is_superhost'].map({False:'No',True:'Yes'})
df_host['host_has_profile_pic'] = df_host['host_has_profile_pic'].map({False:'No',True:'Yes'})
df_host['host_identity_verified'] = df_host['host_identity_verified'].map({False:'No',True:'Yes'})
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0   1003530    454250    https://www.airbnb.com/users/show/454250
# 1  10133554  52004703  https://www.airbnb.com/users/show/52004703
# 2  10059872  51624384  https://www.airbnb.com/users/show/51624384
# 3  10084023  51744313  https://www.airbnb.com/users/show/51744313
# 4  10091713  13764143  https://www.airbnb.com/users/show/13764143
#
#      host_name                      host_location  host_response_time  \
# 0        Greta  New York, New York, United States      within an hour
# 1  Mehmet Emin         Istanbul, İstanbul, Turkey  within a few hours
# 2     Giovanni               Hong Kong, Hong Kong       Not Specified
# 3           Yi                      United States      within an hour
# 4          Ben         New South Wales, Australia       Not Specified
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/f1022be4-e...
# 1  https://a0.muscache.com/im/pictures/user/4cb6b...
# 2  https://a0.muscache.com/im/pictures/264b82a7-7...
# 3  https://a0.muscache.com/im/pictures/user/a204d...
# 4  https://a0.muscache.com/im/pictures/03c4d82b-7...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 1  https://a0.muscache.com/im/pictures/user/4cb6b...      Not Specified
# 2  https://a0.muscache.com/im/pictures/264b82a7-7...               Soho
# 3  https://a0.muscache.com/im/pictures/user/a204d...       Shek Kip Mei
# 4  https://a0.muscache.com/im/pictures/03c4d82b-7...        Surry Hills
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                100               Yes                  Yes
# 1                100                No                  Yes
# 2      Not Specified                No                  Yes
# 3                100                No                  Yes
# 4      Not Specified                No                  Yes
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    Yes                    3                          3
# 1                    Yes                    2                          2
# 2                     No                    1                          1
# 3                    Yes                    2                          2
# 4                    Yes                    1                          1
#
#                                   host_verifications
# 0  [email, phone, reviews, jumio, offline_governm...
# 1  [email, phone, facebook, reviews, jumio, offli...
# 2      [email, phone, reviews, jumio, government_id]
# 3  [email, phone, reviews, jumio, offline_governm...
# 4  [email, phone, google, reviews, jumio, offline...

# %%
df_host.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_response_time           0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
df_host.dtypes
# Out:
# _id                          object
# host_id                      object
# host_url                     object
# host_name                    object
# host_location                object
# host_response_time           object
# host_thumbnail_url           object
# host_picture_url             object
# host_neighbourhood           object
# host_response_rate           object
# host_is_superhost            object
# host_has_profile_pic         object
# host_identity_verified       object
# host_listings_count           int64
# host_total_listings_count     int64
# host_verifications           object
# dtype: object

# %% [markdown]
# **Address**

# %%
address = []
for i in col.find( {}, {'_id':1, 'address':1}):
    address.append(i)

df_address = pd.DataFrame(address)
address_keys = list(df_address.iloc[0,1].keys())

for i in address_keys:
    if i == 'location':
        df_address['location_type'] = df_address['address'].apply(lambda x: x['location']['type'])
        df_address['longitude'] = df_address['address'].apply(lambda x: x['location']['coordinates'][0])
        df_address['latitude'] = df_address['address'].apply(lambda x: x['location']['coordinates'][1])
        df_address['is_location_exact'] = df_address['address'].apply(lambda x: x['location']['is_location_exact'])
    else:
        df_address[i] = df_address['address'].apply(lambda x: x[i] if x[i]!='' else 'Not Specified')

df_address.drop(columns=['address'], inplace=True)
df_address.head()
# Out:
#         _id                                  street  \
# 0   1003530             New York, NY, United States
# 1  10133554                Fatih , İstanbul, Turkey
# 2  10059872  Hong Kong, Hong Kong Island, Hong Kong
# 3  10084023               Hong Kong , 九龍, Hong Kong
# 4  10091713             Surry Hills, NSW, Australia
#
#                        suburb    government_area     market        country  \
# 0                   Manhattan    Upper West Side   New York  United States
# 1                       Fatih              Fatih   Istanbul         Turkey
# 2  Central & Western District  Central & Western  Hong Kong      Hong Kong
# 3       Sham Shui Po District       Sham Shui Po  Hong Kong      Hong Kong
# 4                Darlinghurst             Sydney     Sydney      Australia
#
#   country_code location_type  longitude  latitude  is_location_exact
# 0           US         Point  -73.96523  40.79962              False
# 1           TR         Point   28.98009  41.00620              False
# 2           HK         Point  114.15027  22.28158               True
# 3           HK         Point  114.16690  22.33140               True
# 4           AU         Point  151.21554 -33.88029               True

# %%
df_address['is_location_exact'] = df_address['is_location_exact'].map({False:'No',True:'Yes'})
df_address.head()
# Out:
#         _id                                  street  \
# 0   1003530             New York, NY, United States
# 1  10133554                Fatih , İstanbul, Turkey
# 2  10059872  Hong Kong, Hong Kong Island, Hong Kong
# 3  10084023               Hong Kong , 九龍, Hong Kong
# 4  10091713             Surry Hills, NSW, Australia
#
#                        suburb    government_area     market        country  \
# 0                   Manhattan    Upper West Side   New York  United States
# 1                       Fatih              Fatih   Istanbul         Turkey
# 2  Central & Western District  Central & Western  Hong Kong      Hong Kong
# 3       Sham Shui Po District       Sham Shui Po  Hong Kong      Hong Kong
# 4                Darlinghurst             Sydney     Sydney      Australia
#
#   country_code location_type  longitude  latitude is_location_exact
# 0           US         Point  -73.96523  40.79962                No
# 1           TR         Point   28.98009  41.00620                No
# 2           HK         Point  114.15027  22.28158               Yes
# 3           HK         Point  114.16690  22.33140               Yes
# 4           AU         Point  151.21554 -33.88029               Yes

# %%
df_address.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
df_address.dtypes
# Out:
# _id                   object
# street                object
# suburb                object
# government_area       object
# market                object
# country               object
# country_code          object
# location_type         object
# longitude            float64
# latitude             float64
# is_location_exact     object
# dtype: object

# %% [markdown]
# **Availability**

# %%
availability = []
for i in col.find( {}, {'_id':1, 'availability':1}):
    availability.append(i)

df_availability = pd.DataFrame(availability)
availability_keys = list(df_availability.iloc[0,1].keys())

for i in availability_keys:
    df_availability['availability_30'] = df_availability['availability'].apply(lambda x: x['availability_30'])
    df_availability['availability_60'] = df_availability['availability'].apply(lambda x: x['availability_60'])
    df_availability['availability_90'] = df_availability['availability'].apply(lambda x: x['availability_90'])
    df_availability['availability_365'] = df_availability['availability'].apply(lambda x: x['availability_365'])

df_availability.drop(columns=['availability'], inplace=True)
df_availability.head()
# Out:
#         _id  availability_30  availability_60  availability_90  \
# 0   1003530                0                0                0
# 1  10133554               30               60               90
# 2  10059872                0                0                0
# 3  10084023               14               24               40
# 4  10091713                0                0                0
#
#    availability_365
# 0                93
# 1               365
# 2                 0
# 3               220
# 4                 0

# %%
df_availability.isnull().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
df_availability.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %% [markdown]
# **Amenities**

# %%
def amenities_sort(x):
    a = x
    a.sort(reverse=False)
    return a

amenities = []
for i in col.find( {}, {'_id':1, 'amenities':1}):
    amenities.append(i)

df_amenities = pd.DataFrame(amenities)
df_amenities['amenities'] = df_amenities['amenities'].apply(lambda x: amenities_sort(x))
df_amenities.head()
# Out:
#         _id                                          amenities
# 0   1003530  [Air conditioning, Buzzer/wireless intercom, D...
# 1  10133554  [Air conditioning, Building staff, Dryer, Esse...
# 2  10059872  [24-hour check-in, Air conditioning, Doorman, ...
# 3  10084023  [Air conditioning, Dishes and silverware, Elev...
# 4  10091713  [Bed linens, Dryer, Elevator, Essentials, Ethe...

# %%
df_amenities.isnull().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %%
df_amenities.dtypes
# Out:
# _id          object
# amenities    object
# dtype: object

# %%
df = pd.merge(df_1, df_host, on='_id')
df = pd.merge(df, df_address, on='_id')
df = pd.merge(df, df_availability, on='_id')
df = pd.merge(df, df_amenities, on='_id')
df.head(3)
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
#
#                                   name      property_type        room_type  \
# 0  New York City - Upper West Side Apt          Apartment     Private room
# 1  Double and triple rooms Blue mosque  Bed and breakfast     Private room
# 2   Soho Cozy, Spacious and Convenient          Apartment  Entire home/apt
#
#    bed_type  minimum_nights  maximum_nights          cancellation_policy  \
# 0  Real Bed              12             360  strict_14_with_grace_period
# 1  Real Bed               1            1125                     moderate
# 2  Real Bed               4              20                     flexible
#
#    accommodates  bedrooms  beds  number_of_reviews  bathrooms  price  \
# 0             2         1     1                 70        1.0    135
# 1             3         1     2                 29        1.0    121
# 2             3         1     2                  3        1.0    699
#
#     cleaning_fee  extra_people  guests_included  \
# 0            135             0                1
# 1  Not Specified             0                1
# 2  Not Specified             0                1
#
#                                               images  review_scores   host_id  \
# 0  https://a0.muscache.com/im/pictures/15074036/a...             94    454250
# 1  https://a0.muscache.com/im/pictures/68de30b5-e...             92  52004703
# 2  https://a0.muscache.com/im/pictures/4533a1dc-6...            100  51624384
#
#                                      host_url    host_name  \
# 0    https://www.airbnb.com/users/show/454250        Greta
# 1  https://www.airbnb.com/users/show/52004703  Mehmet Emin
# 2  https://www.airbnb.com/users/show/51624384     Giovanni
#
#                        host_location  host_response_time  \
# 0  New York, New York, United States      within an hour
# 1         Istanbul, İstanbul, Turkey  within a few hours
# 2               Hong Kong, Hong Kong       Not Specified
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/f1022be4-e...
# 1  https://a0.muscache.com/im/pictures/user/4cb6b...
# 2  https://a0.muscache.com/im/pictures/264b82a7-7...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 1  https://a0.muscache.com/im/pictures/user/4cb6b...      Not Specified
# 2  https://a0.muscache.com/im/pictures/264b82a7-7...               Soho
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                100               Yes                  Yes
# 1                100                No                  Yes
# 2      Not Specified                No                  Yes
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    Yes                    3                          3
# 1                    Yes                    2                          2
# 2                     No                    1                          1
#
#                                   host_verifications  \
# 0  [email, phone, reviews, jumio, offline_governm...
# 1  [email, phone, facebook, reviews, jumio, offli...
# 2      [email, phone, reviews, jumio, government_id]
#
#                                    street                      suburb  \
# 0             New York, NY, United States                   Manhattan
# 1                Fatih , İstanbul, Turkey                       Fatih
# 2  Hong Kong, Hong Kong Island, Hong Kong  Central & Western District
#
#      government_area     market        country country_code location_type  \
# 0    Upper West Side   New York  United States           US         Point
# 1              Fatih   Istanbul         Turkey           TR         Point
# 2  Central & Western  Hong Kong      Hong Kong           HK         Point
#
#    longitude  latitude is_location_exact  availability_30  availability_60  \
# 0  -73.96523  40.79962                No                0                0
# 1   28.98009  41.00620                No               30               60
# 2  114.15027  22.28158               Yes                0                0
#
#    availability_90  availability_365  \
# 0                0                93
# 1               90               365
# 2                0                 0
#
#                                            amenities
# 0  [Air conditioning, Buzzer/wireless intercom, D...
# 1  [Air conditioning, Building staff, Dryer, Esse...
# 2  [24-hour check-in, Air conditioning, Doorman, ...

# %%
# download as csv
df.to_csv('airbnb.csv', index=False)

# %%
df.dtypes
# Out:
# _id                           object
# listing_url                   object
# name                          object
# property_type                 object
# room_type                     object
# bed_type                      object
# minimum_nights                 int32
# maximum_nights                 int32
# cancellation_policy           object
# accommodates                   int64
# bedrooms                       int32
# beds                           int32
# number_of_reviews              int64
# bathrooms                    float64
# price                          int32
# cleaning_fee                  object
# extra_people                   int32
# guests_included                int32
# images                        object
# review_scores                  int64
# host_id                       object
# host_url                      object
# host_name                     object
# host_location                 object
# host_response_time            object
# host_thumbnail_url            object
# host_picture_url              object
# host_neighbourhood            object
# host_response_rate            object
# host_is_superhost             object
# host_has_profile_pic          object
# host_identity_verified        object
# host_listings_count            int64
# host_total_listings_count      int64
# host_verifications            object
# street                        object
# suburb                        object
# government_area               object
# market                        object
# country                       object
# country_code                  object
# location_type                 object
# longitude                    float64
# latitude                     float64
# is_location_exact             object
# availability_30                int64
# availability_60                int64
# availability_90                int64
# availability_365               int64
# amenities                     object
# dtype: object
